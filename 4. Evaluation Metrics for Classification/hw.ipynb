# %% [markdown]
# # 4. Evaluation Metrics for Classification

# %% [markdown]
# ## Setting Import libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.metrics import roc_curve
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Preparation

# %%
df = pd.read_csv('AER_credit_card_data.csv')
df
# Out:
#      card  reports       age  income     share  expenditure owner selfemp  \
# 0     yes        0  37.66667  4.5200  0.033270   124.983300   yes      no
# 1     yes        0  33.25000  2.4200  0.005217     9.854167    no      no
# 2     yes        0  33.66667  4.5000  0.004156    15.000000   yes      no
# 3     yes        0  30.50000  2.5400  0.065214   137.869200    no      no
# 4     yes        0  32.16667  9.7867  0.067051   546.503300   yes      no
# ...   ...      ...       ...     ...       ...          ...   ...     ...
# 1314  yes        0  33.58333  4.5660  0.002146     7.333333   yes      no
# 1315   no        5  23.91667  3.1920  0.000376     0.000000    no      no
# 1316  yes        0  40.58333  4.6000  0.026513   101.298300   yes      no
# 1317  yes        0  32.83333  3.7000  0.008999    26.996670    no     yes
# 1318  yes        0  48.25000  3.7000  0.111619   344.157500   yes      no
#
#       dependents  months  majorcards  active
# ...

# %% [markdown]
# ### Data Preprocessing

# %%
def standardize_cat_series(column: pd.Series):
    return column.str.lower().str.replace(' ', '_')

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')
categorical_columns = [col for col in df.select_dtypes('object').columns]

# %%
for col in categorical_columns:
    df[col] = standardize_cat_series(df[col])

# %%
df.totalcharges = pd.to_numeric(df.totalcharges, errors='coerce').fillna(0)
df.churn = (df.churn == 'yes').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_516428/782447341.py in <module>
# ----> 1 df.totalcharges = pd.to_numeric(df.totalcharges, errors='coerce').fillna(0)
#       2 df.churn = (df.churn == 'yes').astype(int)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'totalcharges'
